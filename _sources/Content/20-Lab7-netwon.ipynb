# %% [markdown]
# # Lab 7: numerical estimation for Logistic regression
#
# Recall that to estimate the regression coefficients in logistic regression, we need to maximize the associated likelihood function
#
# $$
# l(\beta) = \sum_{i=1}^n [y_i x_i^T \beta -  \log(1+e^{x_i^T \beta})].
# $$
#
# Recall the [PyTorch](S-pytorch) can be used to efficiently optimize functions
